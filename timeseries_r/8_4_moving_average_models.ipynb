# %% [markdown]
# ARIMA(p, d, q)
#
#  - p = order of autoregressive part
#  - d = degree of first differencing involved
#  - q order of the moving average part
#
# so MA(2) model = (0,0,2)?

# %%
source(file = "util.r")

install_packages(c('ggplot2', 'zoo', 'forecast'), quietly = T, warn.conflicts = F)

# %%
fit <- arima(AirPassengers, order=c(0,0,2), list(order=c(0,0,2)), method="ML")
fit
# Out:
# Call:
# arima(x = AirPassengers, order = c(0, 0, 2), seasonal = list(order = c(0, 0,
#     2)), method = "ML")
#
# Coefficients:
#          ma1     ma2    sma1   sma2  intercept
#       1.0433  0.6842  1.1803  1.000   285.6752
# s.e.  0.1048  0.0604  0.1606  0.186    14.8745
#
# sigma^2 estimated as 498.1:  log likelihood = -678.36,  aic = 1368.71

# %%
library(repr)
options(repr.plot.width=6, repr.plot.height=3)

autoplot(forecast(fit, h=10))
# Out:
# plot without title
