# %% [markdown]
# ARIMA(p, d, q)
#
#  - p = order of autoregressive part
#  - d = degree of first differencing involved
#  - q order of the moving average part
#
# so MA(2) model = (0,0,2)?

# %%
source(file = "util.r")

install_packages(c('ggplot2', 'zoo', 'forecast'), quietly = T, warn.conflicts = F)

# %%
fit <- arima(AirPassengers, order=c(0,0,2), list(order=c(0,0,2)))
fit
# Out:
# Call:
# arima(x = AirPassengers, order = c(0, 0, 2), seasonal = list(order = c(0, 0,
#     2)))
#
# Coefficients:
#          ma1     ma2    sma1    sma2  intercept
#       0.9663  0.6839  1.3443  0.6947   283.3246
# s.e.  0.0770  0.0574  0.1126  0.1084    15.2375
#
# sigma^2 estimated as 596.7:  log likelihood = -679.02,  aic = 1370.05

# %%
library(repr)
options(repr.plot.width=6, repr.plot.height=3)

autoplot(forecast(fit, h=10))
# Out:
# plot without title

# %%
fit <- auto.arima(AirPassengers)
fit
# Out:
# Series: AirPassengers
# ARIMA(2,1,1)(0,1,0)[12]
#
# Coefficients:
#          ar1     ar2      ma1
#       0.5960  0.2143  -0.9819
# s.e.  0.0888  0.0880   0.0292
#
# sigma^2 estimated as 132.3:  log likelihood=-504.92
# AIC=1017.85   AICc=1018.17   BIC=1029.35

# %%
autoplot(forecast(fit, h=10))
# Out:
# plot without title
