# %%
source(file = "util.r")

install_packages(c('ggplot2', 'zoo', 'forecast', 'quantmod'), quietly = T, warn.conflicts = F)

library(repr)
options(repr.plot.width=6, repr.plot.height=3)
# Out:
# Version 0.4-0 included new data defaults. See ?getSymbols.

# %% [markdown]
# ### Seasonal and Trend

# %%
autoplot(AirPassengers) +
  ggtitle("AirPassengers") +
  xlab("Year") +
  ylab("# Travellers (000s)")
# Out:
# plot without title

# %%
ggseasonplot(AirPassengers, year.labels=TRUE, year.labels.left=TRUE) +
  ylab("# Travellers (000s)") +
  ggtitle("AirPassengers")
# Out:
# plot without title

# %%
options(repr.plot.width=6, repr.plot.height=6)

ggseasonplot(AirPassengers, year.labels=TRUE, year.labels.left=TRUE, polar = TRUE) +
  ylab("# Travellers (000s)") +
  ggtitle("AirPassengers")
# Out:
# plot without title
