# %% [markdown]
# ### White noise
#
# Generate some white noise and inspect the autocorrelation function plot

# %%
# %matplotlib inline

import numpy as np
import pandas as pd
from statsmodels.graphics.tsaplots import plot_acf, acf
import matplotlib.pyplot as plt

# %%
index = pd.date_range('2015-07-03', periods=500, freq='D')
index
# Out:
# DatetimeIndex(['2015-07-03', '2015-07-04', '2015-07-05', '2015-07-06',
#                '2015-07-07', '2015-07-08', '2015-07-09', '2015-07-10',
#                '2015-07-11', '2015-07-12',
#                ...
#                '2016-11-04', '2016-11-05', '2016-11-06', '2016-11-07',
#                '2016-11-08', '2016-11-09', '2016-11-10', '2016-11-11',
#                '2016-11-12', '2016-11-13'],
#               dtype='datetime64[ns]', length=500, freq='D')

# %%
data = np.random.normal(loc=0, scale=1, size=500)

# %%
wn = pd.DataFrame(index=index, data=data, columns=['wn'])
wn.head(5)
# Out:
#                   wn
# 2015-07-03  0.242157
# 2015-07-04  0.475511
# 2015-07-05 -0.301288
# 2015-07-06 -0.180352
# 2015-07-07 -0.111190

# %%
_ = wn.plot()

# %%
plot_acf(wn, alpha=0.05, lags=20) # alpha is confidence interval
plt.show()

# %%
# Uncomment to display acf values
# acf(wn)

# %% [markdown]
# ### Discussion
#
#  - the first bar in the acf chart is always height one
#  - other bars inside confidence interval (mostly) showing there isn't correlation between lags
